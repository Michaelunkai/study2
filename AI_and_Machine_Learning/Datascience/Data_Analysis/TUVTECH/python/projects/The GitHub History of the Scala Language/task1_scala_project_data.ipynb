# %% [markdown]
# # Scala's real-world project repository data
#
# In this notebook, we will explore and clean the data from the Scala GitHub repository. The goal is to understand the project's development history.

# %% [markdown]
# ## Task 1: Instructions
#
# - Import the dataset into the notebook. All relevant files are in the `datasets` subfolder.
# - Import the `pandas` module.
# - Load the following files as `pandas` DataFrames:
#   1. `datasets/pulls_2011-2013.csv` as `pulls_one`
#   2. `datasets/pulls_2014-2018.csv` as `pulls_two`
#   3. `datasets/pull_files.csv` as `pull_files`.

# %%
# Importing pandas module
import pandas as pd

# Loading the data
pulls_one = pd.read_csv('datasets/pulls_2011-2013.csv')
pulls_two = pd.read_csv('datasets/pulls_2014-2018.csv')
pull_files = pd.read_csv('datasets/pull_files.csv')

# Displaying the data to verify
print(pulls_one.head())
print(pulls_two.head())
print(pull_files.head())
