# %% [markdown]
# # Scala's real-world project repository data
#
# In this notebook, we will prepare and clean the data extracted from the Scala GitHub repository.

# %% [markdown]
# ## Task 2: Preparing and Cleaning the Data
#
# - Combine the two pull DataFrames.
# - Convert the `date` column from string to a `DateTime` object.

# %%
# Combine the two DataFrames
pulls = pd.concat([pulls_one, pulls_two])

# Convert the 'date' column to DateTime object
pulls['date'] = pd.to_datetime(pulls['date'], utc=True)

# Display the first few rows to verify the changes
print(pulls.head())
