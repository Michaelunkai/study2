# %% [markdown]
# # Scala's real-world project repository data
#
# In this notebook, we will merge the pull request data with the file data to prepare for further analysis.

# %% [markdown]
# ## Task 3: Merging the DataFrames
#
# - Merge the `pulls` and `pull_files` DataFrames on the `pid` column.
# - Assign the resulting DataFrame to the variable `data`.

# %%
# Merge the two DataFrames on the 'pid' column
data = pd.merge(pulls, pull_files, on='pid')

# Display the first few rows to verify the merge
print(data.head())
